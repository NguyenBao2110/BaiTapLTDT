# %% [markdown]
# # Thực Hành

# %% [markdown]
# # Chương 7

# %% [markdown]
# Ý tưởng

# %%
print("•	Bắt đầu từ một đỉnh (ở đây là đỉnh 1).")
print("")
print("•	Mỗi bước, chọn đỉnh chưa thăm có cạnh nối nhỏ nhất đến cây hiện tại..")
print("")
print("•	Thêm đỉnh đó và cạnh nối vào cây khung.")
print("")
print("•	Cập nhật khoảng cách (trọng số nhỏ nhất) từ các đỉnh còn lại đến cây.")
print("")
print("•	Lặp lại cho đến khi tất cả các đỉnh được thêm vào cây hoặc không còn cạnh nối.")
print("")
print("➡️ Kết quả: thu được cây khung nhỏ nhất (Minimum Spanning Tree) cùng tổng trọng số tối thiểu.")
# Out:
# •	Bắt đầu từ một đỉnh (ở đây là đỉnh 1).
#
# •	Mỗi bước, chọn đỉnh chưa thăm có cạnh nối nhỏ nhất đến cây hiện tại..
#
# •	Thêm đỉnh đó và cạnh nối vào cây khung.
#
# •	Cập nhật khoảng cách (trọng số nhỏ nhất) từ các đỉnh còn lại đến cây.
#
# •	Lặp lại cho đến khi tất cả các đỉnh được thêm vào cây hoặc không còn cạnh nối.
#
# ➡️ Kết quả: thu được cây khung nhỏ nhất (Minimum Spanning Tree) cùng tổng trọng số tối thiểu.

# %%
print("---- Code ----")
# !cat PRIM.cpp
# Out:
# ---- Code ----
# #include <iostream>
# #include <vector>
# #include <map>
# #include <limits>
# using namespace std;
#
# const int INF = 1e9;
# vector<map<int, int>> adj;
# vector<bool> visited;
# vector<int> nearNode, pre;
# vector<pair<int, int>> tree;
# int n, m;
#
# void Prim() {
#     visited.assign(n + 1, false);
#     nearNode.assign(n + 1, INF);
#     pre.assign(n + 1, -1);
#     tree.clear();
#
#     int s = 1; // bắt đầu từ đỉnh 1
#     nearNode[s] = 0;
#
#     for (int i = 1; i <= n; i++) {
#         int uMin = -1;
#
#         // Tìm đỉnh chưa thăm có trọng số nhỏ nhất
#         for (int u = 1; u <= n; u++) {
#             if (!visited[u] && (uMin == -1 || nearNode[u] < nearNode[uMin])) {
#                 uMin = u;
#             }
#         }
#
#         if (uMin == -1) break; // không còn đỉnh nào
#
#         visited[uMin] = true;
#
#         // Nếu không phải là đỉnh bắt đầu thì thêm cạnh vào cây khung
#         if (pre[uMin] != -1)
# ...

# %%
# !cat PRIM.in
# Out:
# 7 12
# 1 2 8
# 1 3 5
# 2 3 10
# 2 4 2
# 2 5 18
# 3 4 3
# 3 6 16
# 4 5 12
# 4 6 30
# 4 7 14
# 5 7 4
# 6 7 26

# %%
# !g++ PRIM.cpp -o PRIM
# !./PRIM < PRIM.in
# Out:
# Cac canh thuoc cay khung nho nhat:
# 1 - 3 : 5
# 3 - 4 : 3
# 4 - 2 : 2
# 4 - 5 : 12
# 5 - 7 : 4
# 3 - 6 : 16
# Tong trong so cay khung = 42

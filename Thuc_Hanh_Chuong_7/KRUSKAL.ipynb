# %% [markdown]
# # Thực Hành

# %% [markdown]
# # Chương 7

# %% [markdown]
# Bài 3. Kruskal

# %% [markdown]
# Ý tưởng:

# %%
print("Xem mỗi đỉnh như một tập riêng biệt (disjoint set).")
print("")
print("Sắp xếp toàn bộ cạnh theo trọng số tăng dần.")
print("")
print("  Duyệt lần lượt các cạnh:")
print("")
print("•	Nếu hai đỉnh của cạnh nằm ở hai tập khác nhau → chọn cạnh này vào cây và hợp hai tập lại.")
print("")
print("•	Nếu hai đỉnh đã nằm trong cùng một tập → bỏ qua (vì sẽ tạo chu trình).")
# Out:
# Xem mỗi đỉnh như một tập riêng biệt (disjoint set).
#
# Sắp xếp toàn bộ cạnh theo trọng số tăng dần.
#
#   Duyệt lần lượt các cạnh:
#
# •	Nếu hai đỉnh của cạnh nằm ở hai tập khác nhau → chọn cạnh này vào cây và hợp hai tập lại.
#
# •	Nếu hai đỉnh đã nằm trong cùng một tập → bỏ qua (vì sẽ tạo chu trình).

# %%
print("---- Code ----")
# !cat KRUSKAL.cpp
# Out:
# ---- Code ----
# #include <iostream>
# #include <vector>
# #include <tuple>
# #include <algorithm>
# using namespace std;
#
# int n, m;
# vector<vector<pair<int, int>>> adj;
#
# void Make_Tree() {
#     vector<tuple<int, int, int>> edges;
#     // Tạo danh sách cạnh
#     for (int u = 1; u <= n; u++) {
#         for (auto p : adj[u]) {
#             int v = p.first;
#             int w = p.second;
#             if (u < v)
#                 edges.push_back({ w, u, v });
#         }
#     }
#
#     sort(edges.begin(), edges.end());
#
#     vector<int> connected(n + 1);
#     for (int i = 1; i <= n; i++)
#         connected[i] = i;
#
#     vector<pair<int, int>> tree(n + 1, { -1, 0 });
#     long long total = 0;
#     int edge_count = 0; // ✅ đếm số cạnh trong cây khung
#
#     for (auto edge : edges) {
#         int w = get<0>(edge);
#         int u = get<1>(edge);
#         int v = get<2>(edge);
#
#         if (connected[u] != connected[v]) {
#             int umin = u, vmin = v;
# ...

# %%
# !cat KRUSKAL.in
# Out:
# 7 12
# 1 2 8
# 1 3 5
# 2 3 10
# 2 4 2
# 2 5 18
# 3 4 3
# 3 6 16
# 4 5 12
# 4 6 30
# 4 7 14
# 5 7 4
# 6 7 26

# %%
# !g++ KRUSKAL.cpp -o KRUSKAL
# !./KRUSKAL < KRUSKAL.in
# Out:
# 6 42
# 1 3 5
# 3 4 3
# 4 5 12
# 3 6 16
# 5 7 4
